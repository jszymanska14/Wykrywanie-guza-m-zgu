# %%
# !pip install tqdm
# !pip install opencv-python
# !pip install tensorflow
# Out:
# ...
# WARNING: You are using pip version 21.3.1; however, version 24.0 is available.
# You should consider upgrading via the '/Users/juliaszymanska/PycharmProjects/MNE/venv/bin/python -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 21.3.1; however, version 24.0 is available.
# You should consider upgrading via the '/Users/juliaszymanska/PycharmProjects/MNE/venv/bin/python -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 21.3.1; however, version 24.0 is available.
# You should consider upgrading via the '/Users/juliaszymanska/PycharmProjects/MNE/venv/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install torch
# Out:
# ...
# WARNING: You are using pip version 21.3.1; however, version 24.0 is available.
# You should consider upgrading via the '/Users/juliaszymanska/PycharmProjects/MNE/venv/bin/python -m pip install --upgrade pip' command.

# %%
from tqdm import tqdm
import os
from sklearn.utils import shuffle



# Nazwy folderów z klasami
labels = {'no': 0, 'yes': 1}

# Rozmiar obrazu po przeskalowaniu
image_size = 228


def load_data(folder_path, image_size):
    X = []
    y = []
    for label, label_index in labels.items():
        class_path = os.path.join(folder_path, label)
        for filename in tqdm(os.listdir(class_path)):
            img_path = os.path.join(class_path, filename)
          
            img = cv2.imread(img_path)
            
            img = cv2.resize(img, (image_size, image_size))
            # Dodanie wymiaru
            img = np.expand_dims(img, axis=0)
            # Dodanie obrazu do listy X
            X.append(img)
            # Dodanie etykiety do listy y
            y.append(label_index)
    return np.array(X), np.array(y)


X_train, y_train = load_data('/Users/juliaszymanska/PycharmProjects/zastosowanie_sieci_neuronowych/train', image_size)


X_test, y_test = load_data('/Users/juliaszymanska/PycharmProjects/zastosowanie_sieci_neuronowych/test', image_size)


X_val, y_val = load_data('/Users/juliaszymanska/PycharmProjects/zastosowanie_sieci_neuronowych/valid', image_size)


X_train, y_train = shuffle(X_train, y_train, random_state=101)

# Wyświetlanie rozmiaru zbiorów
"""""
print(f"Rozmiar zbioru uczącego: {X_train.shape[0]}")
print(f"Rozmiar zbioru testowego: {X_test.shape[0]}")
print(f"Rozmiar zbioru walidacyjnego: {X_val.shape[0]}")
"""""
# Out:
# ...
#  15%|█▌        | 16/104 [00:00<00:00, 461.06it/s]
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[13], line 37
#      31     return np.array(X), np.array(y)
#      34 X_train, y_train = load_data('/Users/juliaszymanska/PycharmProjects/zastosowanie_sieci_neuronowych/train', image_size)
# ---> 37 X_test, y_test = load_data('/Users/juliaszymanska/PycharmProjects/zastosowanie_sieci_neuronowych/test', image_size)
#      40 X_val, y_val = load_data('/Users/juliaszymanska/PycharmProjects/zastosowanie_sieci_neuronowych/valid', image_size)
#      43 X_train, y_train = shuffle(X_train, y_train, random_state=101)
#
# Cell In[13], line 24, in load_data(folder_path, image_size)
#      20 img_path = os.path.join(class_path, filename)
#      22 img = cv2.imread(img_path)
# ---> 24 img = cv2.resize(img, (image_size, image_size))
#      25 # Dodanie wymiaru
# ...

# %%
import numpy as np

# Przykład danych obrazów
X = np.random.rand(5, 224, 224, 3)  


dtype = X.dtype
print(f"Typ danych w X: {dtype}")

# Sprawdzenie, czy dane są typu float
if np.issubdtype(dtype, np.floating):
    print("Dane są typu float.")

# Sprawdzenie, czy dane są typu int
if np.issubdtype(dtype, np.integer):
    print("Dane są typu int.")
# Out:
# Typ danych w X: float64
# Dane są typu float.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import os


# Nazwy folderów z klasami
labels = {'no': 0, 'yes': 1}

# Rozmiar obrazu po przeskalowaniu
image_size = 224

# Funkcja do wczytywania danych z folderu
def load_data(folder_path, image_size):
    X = []
    y = []
    for label, label_index in labels.items():
        class_path = os.path.join(folder_path, label)
        print(f"Checking directory: {class_path}")
        if not os.path.exists(class_path):
            print(f"Directory does not exist: {class_path}")
            continue
        for filename in tqdm(os.listdir(class_path)):
            img_path = os.path.join(class_path, filename)
            print(f"Loading image: {img_path}")
            img = cv2.imread(img_path)
            if img is None:
                print(f"Failed to load image: {img_path}")
                continue
            img = cv2.resize(img, (image_size, image_size))
            img = np.expand_dims(img, axis=0)
            X.append(img)
            y.append(label_index)
    return np.array(X), np.array(y)


X_train, y_train = load_data('/https:/github.com/jszymanska14/Wykrywanie-guza-m-zgu.git/train', image_size)


X_test, y_test = load_data('/https:/github.com/jszymanska14/Wykrywanie-guza-m-zgu.git/test', image_size)


X_val, y_val = load_data('/https:/github.com/jszymanska14/Wykrywanie-guza-m-zgu.git/valid', image_size)


datasets = [('Trening', X_train, y_train), ('Testowy', X_test, y_test), ('Walidacyjny', X_val, y_val)]

# Zdefiniowanie słownika mapującego etykiety (0 i 1) na nazwy klas
labels = {0: 'no', 1: 'yes'}


for dataset_name, X, y in datasets:
   
    # Liczba obrazów dla każdej klasy
    counts = pd.Series(y).value_counts()
    print(f"Liczba obrazów dla każdej klasy w zbiorze {dataset_name}")
    print(counts)
    
    # Wykres słupkowy przedstawiający rozkład klas
    plt.figure(figsize=(6, 10))
    sns.countplot(x=y)
    plt.xlabel('Klasa')
    plt.ylabel('Liczba obrazów')
    plt.title(f'Rozkład klas w zbiorze {dataset_name}')
    plt.show()

    
    sizes = np.array([img.shape for img in X])
    print(f"\nStatystyki obrazów w zbiorze {dataset_name}")
    print(f"Średni rozmiar obrazów: {np.mean(sizes, axis=0)}")
    print(f"Maksymalny rozmiar obrazów: {np.max(sizes, axis=0)}")
    print(f"Minimalny rozmiar obrazów: {np.min(sizes, axis=0)}")

    # Wyświetlenie kilku przykładowych obrazów z różnych klas
    plt.figure(figsize=(10, 5))
    for i, label in enumerate([0, 1]): 
        
        index = np.where(y == label)[0][0]
       
        plt.subplot(1, 2, i + 1)
        plt.imshow(X[index][0]) 
                   #,cmap='gray')
        plt.title(f'Klasa: {labels[label]}')
        plt.axis('off')
    plt.suptitle(f'Przykładowe obrazy z klas w zbiorze {dataset_name}')
    plt.show()
# Out:
# Checking directory: /https:/github.com/jszymanska14/Wykrywanie-guza-m-zgu.git/train/no
# Directory does not exist: /https:/github.com/jszymanska14/Wykrywanie-guza-m-zgu.git/train/no
# Checking directory: /https:/github.com/jszymanska14/Wykrywanie-guza-m-zgu.git/train/yes
# Directory does not exist: /https:/github.com/jszymanska14/Wykrywanie-guza-m-zgu.git/train/yes
# Checking directory: /https:/github.com/jszymanska14/Wykrywanie-guza-m-zgu.git/test/no
# Directory does not exist: /https:/github.com/jszymanska14/Wykrywanie-guza-m-zgu.git/test/no
# Checking directory: /https:/github.com/jszymanska14/Wykrywanie-guza-m-zgu.git/test/yes
# Directory does not exist: /https:/github.com/jszymanska14/Wykrywanie-guza-m-zgu.git/test/yes
# Checking directory: /https:/github.com/jszymanska14/Wykrywanie-guza-m-zgu.git/valid/no
# Directory does not exist: /https:/github.com/jszymanska14/Wykrywanie-guza-m-zgu.git/valid/no
# ...

# %%
import glob
import numpy as np
import cv2
from torch.utils.data import Dataset, DataLoader
import torch
from torch import nn
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

class MRI(Dataset):
    def __init__(self, train_data_path=None, val_data_path=None):
        self.train_data = None
        self.val_data = None
        self.train_images = None
        self.val_images = None
        self.train_labels = None
        self.val_labels = None
        if train_data_path:
            self.load_train_data(train_data_path)
        if val_data_path:
            self.load_validation_data(val_data_path)
        
    def load_train_data(self, train_data_path):
        # Wczytywanie danych treningowych
        tumor = []
        healthy = []
        
        for f in glob.iglob(f'{train_data_path}/no/*.jpg'):
            img = cv2.imread(f)
            if img is not None:
                # Przetwarzanie obrazów zdrowych
                img = cv2.resize(img, (128, 128)) 
                b, g, r = cv2.split(img)
                img = cv2.merge([r, g, b])
                img = np.transpose(img, (2, 0, 1))
                healthy.append(img)
            else:
                print("Błąd podczas ładowania obrazu:", f)

        for f in glob.iglob(f'{train_data_path}/yes/*.jpg'):
            img = cv2.imread(f)
            if img is not None:
                # Przetwarzanie obrazów z guzem
                img = cv2.resize(img, (128, 128)) 
                b, g, r = cv2.split(img)
                img = cv2.merge([r, g, b])
                img = np.transpose(img, (2, 0, 1))
                tumor.append(img)
            else:
                print("Błąd podczas ładowania obrazu:", f)

        # Konwersja list do tablic numpy
        tumor = np.array(tumor, dtype=np.float32)
        healthy = np.array(healthy, dtype=np.float32)
        
        # Tworzenie etykiet
        tumor_label = np.ones(tumor.shape[0], dtype=np.float32)
        healthy_label = np.zeros(healthy.shape[0], dtype=np.float32)
        
        # Łączenie obrazów i etykiet
        self.train_images = np.concatenate((tumor, healthy), axis=0)
        self.train_labels = np.concatenate((tumor_label, healthy_label))
        
        self.train_data = list(zip(self.train_images, self.train_labels))

    def load_validation_data(self, val_data_path):
        # Wczytywanie danych walidacyjnych
        tumor = []
        healthy = []

        for f in glob.iglob(f'{val_data_path}/no/*.jpg'):
            img = cv2.imread(f)
            if img is not None:
                # Przetwarzanie obrazów zdrowych
                img = cv2.resize(img, (128, 128))
                b, g, r = cv2.split(img)
               

                img = cv2.merge([r, g, b])
                img = np.transpose(img, (2, 0, 1))
                healthy.append(img)
            else:
                print("Błąd podczas ładowania obrazu:", f)

        for f in glob.iglob(f'{val_data_path}/yes/*.jpg'):
            img = cv2.imread(f)
            if img is not None:
                # Przetwarzanie obrazów z guzem
                img = cv2.resize(img, (128, 128))
                b, g, r = cv2.split(img)
                img = cv2.merge([r, g, b])
                img = np.transpose(img, (2, 0, 1))
                tumor.append(img)
            else:
                print("Błąd podczas ładowania obrazu:", f)

        # Konwersja list do tablic numpy
        tumor = np.array(tumor, dtype=np.float32)
        healthy = np.array(healthy, dtype=np.float32)

        # Tworzenie etykiet
        tumor_label = np.ones(tumor.shape[0], dtype=np.float32)
        healthy_label = np.zeros(healthy.shape[0], dtype=np.float32)

        # Łączenie obrazów i etykiet
        self.val_images = np.concatenate((tumor, healthy), axis=0)
        self.val_labels = np.concatenate((tumor_label, healthy_label))

        self.val_data = list(zip(self.val_images, self.val_labels))
        
    def __len__(self):
        # Zwracanie długości zbioru danych
        if self.train_data is not None:
            return len(self.train_data)
        elif self.val_data is not None:
            return len(self.val_data)
        else:
            return 0
    
    def __getitem__(self, index):
        # Pobieranie elementu ze zbioru danych
        if self.train_data is not None:
            image, label = self.train_data[index]
        elif self.val_data is not None:
            image, label = self.val_data[index]
        else:
            raise ValueError("Ani train_data, ani val_data nie są dostępne.")
        return {'image': image, 'label': label}
        
    def len_val(self):
        # Zwracanie długości zbioru walidacyjnego
        return len(self.val_data)
    
    def get_val_item(self, index):
        # Pobieranie elementu ze zbioru walidacyjnego
        image, label = self.val_data[index]
        return {'image': image, 'label': label}
    
    def normalize(self):
        # Normalizacja obrazów
        if self.train_images is not None:
            self.train_images = (self.train_images / 255.0 - 0.5) * 2
        if self.val_images is not None:
            self.val_images = (self.val_images / 255.0 - 0.5) * 2

# Wczytywanie danych treningowych i walidacyjnych
mri_dataset_train = MRI(train_data_path='/Users/juliaszymanska/PycharmProjects/projekt_sieci_neuronowe/train')
mri_dataset_val = MRI(val_data_path='/Users/juliaszymanska/PycharmProjects/projekt_sieci_neuronowe/valid')
mri_dataset_train.normalize()
mri_dataset_val.normalize()

# Tworzenie DataLoaderów
train_dataloader = DataLoader(mri_dataset_train, batch_size=128, shuffle=True)
val_dataloader = DataLoader(mri_dataset_val, batch_size=128, shuffle=False)

class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        
        self.cnn_model = nn.Sequential(
            nn.Conv2d(3, 32, 3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(32, 64, 3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(64, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(128, 256, 3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        
        self.fc_model = nn.Sequential(
            nn.Linear(256*8*8, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(512, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(256, 1)
        )
        
    def forward(self, x):
        x = self.cnn_model(x)
        x = x.view(x.size(0), -1)
        x = self.fc_model(x)
        x = torch.sigmoid(x)
        return x


# Ustawienie urządzenia
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = CNN().to(device)
eta = 0.0005
optimizer = torch.optim.Adam(model.parameters(), lr=eta)
loss_function = nn.BCELoss()

# Parametry wczesnego zatrzymywania
early_stopping_patience = 25
min_val_loss = np.inf
patience_counter = 0
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=5, factor=0.5, verbose=True)

EPOCHS = 300
train_losses = []
val_losses = []
val_accuracies = []

for epoch in range(1, EPOCHS + 1):
    model.train()
    train_loss = []
    for batch in train_dataloader:
        images, labels = batch['image'].to(device), batch['label'].to(device)
        labels = labels.view(-1, 1)  
        optimizer.zero_grad()
        outputs = model(images)
        loss = loss_function(outputs, labels)
        loss.backward()
        optimizer.step()
        train_loss.append(loss.item())
    
    avg_train_loss = np.mean(train_loss)
    train_losses.append(avg_train_loss)

    model.eval()
    val_loss = []
    val_predictions = []
    val_labels = []

    with torch.no_grad():
        for batch in val_dataloader:
            images, labels = batch['image'].to(device), batch['label'].to(device)
            labels = labels.view(-1, 1)  
            outputs = model(images)
            loss = loss_function(outputs, labels)
            val_loss.append(loss.item())
            val_predictions.extend(outputs.cpu().numpy())
            val_labels.extend(labels.cpu().numpy())
    
    avg_val_loss = np.mean(val_loss)
    val_losses.append(avg_val_loss)
    
    val_predictions = [1 if pred >= 0.5 else 0 for pred in val_predictions]
    val_accuracy = accuracy_score(val_labels, val_predictions)
    val_accuracies.append(val_accuracy)
    
    print(f'Epoch {epoch}: Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}, Val Accuracy: {val_accuracy:.4f}')

    # Wczesne zatrzymywanie
    scheduler.step(avg_val_loss)
    
    if avg_val_loss < min_val_loss:
        min_val_loss = avg_val_loss
        patience_counter = 0
        torch.save(model.state_dict(), 'best_model.pth')
    else:
        patience_counter += 1
    
    if patience_counter >= early_stopping_patience:
        print("Early stopping triggered.")
        break

# Ładowanie najlepszego modelu
model.load_state_dict(torch.load('best_model.pth'))

# Rysowanie wykresów
plt.style.use('dark_background')
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 7))

ax1.plot(train_losses, label='Train Loss')
ax1.plot(val_losses, label='Val Loss')
ax1.set_title('Train & Val Loss')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()

ax2.plot(val_accuracies, label='Val Accuracy')
ax2.set_title('Val Accuracy')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.legend()

plt.show()
# Out:
# /Users/juliaszymanska/PycharmProjects/MNE/venv/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# Epoch 1: Train Loss: 0.4331, Val Loss: 1.1686, Val Accuracy: 0.3270
# Epoch 2: Train Loss: 0.1933, Val Loss: 0.7843, Val Accuracy: 0.5629
# Epoch 3: Train Loss: 0.0775, Val Loss: 0.8775, Val Accuracy: 0.5752
# Epoch 4: Train Loss: 0.0319, Val Loss: 1.3381, Val Accuracy: 0.5283
# Epoch 5: Train Loss: 0.0131, Val Loss: 1.5834, Val Accuracy: 0.5070
# Epoch 6: Train Loss: 0.0090, Val Loss: 1.5496, Val Accuracy: 0.5292
# Epoch 7: Train Loss: 0.0059, Val Loss: 1.5175, Val Accuracy: 0.5588
# Epoch 8: Train Loss: 0.0037, Val Loss: 1.5509, Val Accuracy: 0.5596
# Epoch 9: Train Loss: 0.0031, Val Loss: 1.4627, Val Accuracy: 0.5768
# Epoch 10: Train Loss: 0.0029, Val Loss: 1.5453, Val Accuracy: 0.5629
# ...

# %%
import torch.nn as nn
import torch.nn.functional as F
import torch



# device will be 'cuda' if a GPU is available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# creating a CPU tensor
cpu_tensor = torch.rand(10).to(device)
# moving same tensor to GPU
gpu_tensor = cpu_tensor.to(device)

print(cpu_tensor, cpu_tensor.dtype, type(cpu_tensor), cpu_tensor.type())
print(gpu_tensor, gpu_tensor.dtype, type(gpu_tensor), gpu_tensor.type())

print(cpu_tensor*gpu_tensor)
# Out:
# tensor([0.1809, 0.9113, 0.2471, 0.3495, 0.7170, 0.5471, 0.9659, 0.4658, 0.3410,
#         0.3339]) torch.float32 <class 'torch.Tensor'> torch.FloatTensor
# tensor([0.1809, 0.9113, 0.2471, 0.3495, 0.7170, 0.5471, 0.9659, 0.4658, 0.3410,
#         0.3339]) torch.float32 <class 'torch.Tensor'> torch.FloatTensor
# tensor([0.0327, 0.8305, 0.0610, 0.1222, 0.5141, 0.2993, 0.9330, 0.2169, 0.1163,
#         0.1115])

# %%
# !pip install torch torchvision torchaudio cudatoolkit=your_cuda_version -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# ERROR: Invalid requirement: 'cudatoolkit=your_cuda_version'
# Hint: = is not a valid operator. Did you mean == ?
# WARNING: You are using pip version 21.3.1; however, version 24.0 is available.
# You should consider upgrading via the '/Users/juliaszymanska/PycharmProjects/MNE/venv/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install torch torchvision torchaudio cudatoolkit=11.1 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# ERROR: Invalid requirement: 'cudatoolkit=11.1'
# Hint: = is not a valid operator. Did you mean == ?
# WARNING: You are using pip version 21.3.1; however, version 24.0 is available.
# You should consider upgrading via the '/Users/juliaszymanska/PycharmProjects/MNE/venv/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install torch torchvision torchaudio
# Out:
# ...
# WARNING: You are using pip version 21.3.1; however, version 24.0 is available.
# You should consider upgrading via the '/Users/juliaszymanska/PycharmProjects/MNE/venv/bin/python -m pip install --upgrade pip' command.

# %%
import matplotlib.pyplot as plt
import numpy as np

images = mri_dataset_train.train_images  
# Przypadkowe próby do wyświetlenia
num_samples_to_visualize = 5  
# Wyświetlanie znormalizowanych obrazów
for i in range(num_samples_to_visualize):
    img = images[i]  
    # Ponieważ img jest w formacie (kanały, wysokość, szerokość), transponujemy go, aby wyświetlić w formacie (wysokość, szerokość, kanały)
    img = np.transpose(img, (1, 2, 0))
    
    plt.imshow(img)
    plt.title(f"Znormalizowany obraz {i + 1}")
    plt.show()
